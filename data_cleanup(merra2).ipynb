# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('merra2(hourly).xlsx',sheet_name='g4.areaAvgTimeSeries.M2T1NXAER_',skiprows=8)

# %%
df
# Out:
#                       time   mean_M2T1NXAER_5_12_4_TOTSCATAU
# 0      2005-01-01 00:30:00                          0.338382
# 1      2005-01-01 01:30:00                          0.354474
# 2      2005-01-01 02:30:00                          0.366277
# 3      2005-01-01 03:30:00                          0.372345
# 4      2005-01-01 04:30:00                          0.372823
# ...                    ...                               ...
# 178219 2025-05-01 19:30:00                          0.686039
# 178220 2025-05-01 20:30:00                          0.691666
# 178221 2025-05-01 21:30:00                          0.708475
# 178222 2025-05-01 22:30:00                          0.732393
# 178223 2025-05-01 23:30:00                          0.759497
#
# [178224 rows x 2 columns]

# %%
df['time'] = pd.to_datetime(df['time'], format='%d-%m-%Y %H:%M')

# %%
df.set_index('time', inplace=True)

# %%
df
# Out:
#                      mean_M2T1NXAER_5_12_4_TOTSCATAU
# time
# 2005-01-01 00:30:00                         0.338382
# 2005-01-01 01:30:00                         0.354474
# 2005-01-01 02:30:00                         0.366277
# 2005-01-01 03:30:00                         0.372345
# 2005-01-01 04:30:00                         0.372823
# ...                                              ...
# 2025-05-01 19:30:00                         0.686039
# 2025-05-01 20:30:00                         0.691666
# 2025-05-01 21:30:00                         0.708475
# 2025-05-01 22:30:00                         0.732393
# 2025-05-01 23:30:00                         0.759497
#
# [178224 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# mean_M2T1NXAER_5_12_4_TOTSCATAU    0
# dtype: int64

# %%
df['AOD_550nm'] = df[' mean_M2T1NXAER_5_12_4_TOTSCATAU'].interpolate(method='linear')

# %%
hourly_df = df.resample('H').mean()
# Out:
# <ipython-input-27-4480fbaa64d7>:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   hourly_df = df.resample('H').mean()

# %%
daily_df = hourly_df.resample('D').mean()

# %%
daily_df.head()
# Out:
#              mean_M2T1NXAER_5_12_4_TOTSCATAU  AOD_550nm
# time
# 2005-01-01                          0.392370   0.392370
# 2005-01-02                          0.789105   0.789105
# 2005-01-03                          1.091180   1.091180
# 2005-01-04                          0.250216   0.250216
# 2005-01-05                          0.275342   0.275342

# %%
daily_df=daily_df.drop(columns=[' mean_M2T1NXAER_5_12_4_TOTSCATAU'])

# %%
daily_df.to_excel('merra2(daily).xlsx')
